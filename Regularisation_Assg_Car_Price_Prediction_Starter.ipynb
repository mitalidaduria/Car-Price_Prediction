# %%
# 1. Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# Keep the output clean
warnings.filterwarnings('ignore')
sns.set_theme(style="whitegrid")

# 2. Load Data (IMPORTANT: Change 'Car_Price_data.csv' to your actual CSV file name!)
df = pd.read_csv('Car_Price_data.csv')

# 3. Take a quick look at the first 5 rows
display(df.head())
